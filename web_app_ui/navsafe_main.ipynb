# %%
# !pip install flask
# !pip install click
# !pip install Werkzeug
# !pip install flask_sqlalchemy

# %%
import os
os.environ["FLASK_APP"] = 'flaskr'
os.environ["FLASK_ENV"] = 'development'

# %%
# !flask run
# Out:
#  * Serving Flask app "flaskr" (lazy loading)
#  * Environment: development
#  * Debug mode: on
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Restarting with fsevents reloader
#  * Debugger is active!
#  * Debugger PIN: 218-325-166
# 127.0.0.1 - - [01/May/2021 15:42:44] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [01/May/2021 15:43:33] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [01/May/2021 15:43:38] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [01/May/2021 15:44:53] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [01/May/2021 15:45:11] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [01/May/2021 15:45:33] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [01/May/2021 15:45:40] "POST / HTTP/1.1" 200 -
# ^C
