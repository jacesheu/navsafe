# %% [markdown]
# This notebook shows how to pull the data from the crime statistics database using Socrata.
# <br>
# The pulled database is then used as input for the modeling files (notebooks named "Modeling").

# %% [markdown]
# # Getting the Data

# %%
import urllib.request
import pandas as pd
from sodapy import Socrata

# %%
client = Socrata("data.sfgov.org", None)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results = client.get("wg3w-h783", limit = 2000000)

# %%
results_df = pd.DataFrame.from_records(results)

# %%
results_df
# Out:
#               incident_datetime            incident_date incident_time  \
# 0       2018-01-01T09:26:00.000  2018-01-01T00:00:00.000         09:26
# 1       2018-01-01T02:30:00.000  2018-01-01T00:00:00.000         02:30
# 2       2018-01-01T10:00:00.000  2018-01-01T00:00:00.000         10:00
# 3       2018-01-01T10:03:00.000  2018-01-01T00:00:00.000         10:03
# 4       2018-01-01T09:01:00.000  2018-01-01T00:00:00.000         09:01
# ...                         ...                      ...           ...
# 445159  2021-03-29T18:30:00.000  2021-03-29T00:00:00.000         18:30
# 445160  2021-04-03T13:25:00.000  2021-04-03T00:00:00.000         13:25
# 445161  2021-04-03T13:58:00.000  2021-04-03T00:00:00.000         13:58
# 445162  2021-04-03T16:30:00.000  2021-04-03T00:00:00.000         16:30
# 445163  2021-03-26T13:30:00.000  2021-03-26T00:00:00.000         13:30
#
#        incident_year incident_day_of_week          report_datetime  \
# 0               2018               Monday  2018-01-01T09:27:00.000
# 1               2018               Monday  2018-01-01T08:21:00.000
# 2               2018               Monday  2018-01-01T10:20:00.000
# 3               2018               Monday  2018-01-01T10:04:00.000
# 4               2018               Monday  2018-01-01T09:39:00.000
# ...              ...                  ...                      ...
# 445159          2021               Monday  2021-03-29T23:44:00.000
# 445160          2021             Saturday  2021-04-03T16:30:00.000
# 445161          2021             Saturday  2021-04-03T14:11:00.000
# 445162          2021             Saturday  2021-04-03T17:24:00.000
# 445163          2021               Friday  2021-03-28T10:50:00.000
#
#               row_id incident_id incident_number cad_number  ...  \
# 0        61893007041      618930       171052174  173641140  ...
# 1        61893105041      618931       180000768  180010668  ...
# 2        61893275000      618932       180000605  180010893  ...
# 3        61893565015      618935       180000887  180011579  ...
# 4        61893607041      618936       171052958  180011403  ...
# ...              ...         ...             ...        ...  ...
# 445159  101847606244     1018476       216035027        NaN  ...
# 445160  101860606244     1018606       210206856  210932079  ...
# 445161  101861304014     1018613       210206492  210931580  ...
# 445162  101862106242     1018621       210206975  210932259  ...
# 445163  101849306244     1018493       216035124        NaN  ...
#
#        :@computed_region_qgnn_b9vv :@computed_region_26cr_cadq  \
# 0                                2                           9
# 1                                9                           1
# 2                                4                          10
# 3                                9                           1
# 4                                6                           3
# ...                            ...                         ...
# 445159                         NaN                         NaN
# 445160                           6                           6
# 445161                           6                           3
# 445162                           4                           6
# 445163                           8                           4
#
#        :@computed_region_ajp5_b2md :@computed_region_6pnf_4xz7  \
# 0                                1                           2
# 1                                7                           2
# 2                               36                           2
# 3                               28                           1
# 4                                6                           2
# ...                            ...                         ...
# 445159                         NaN                         NaN
# 445160                          32                           1
# 445161                          32                           1
# 445162                          27                           1
# 445163                          29                           1
#
#        :@computed_region_h4ep_8xdi :@computed_region_nqbw_i6c3 filed_online  \
# 0                              NaN                         NaN          NaN
# 1                              NaN                         NaN          NaN
# 2                                1                         NaN          NaN
# 3                              NaN                         NaN          NaN
# 4                              NaN                         NaN          NaN
# ...                            ...                         ...          ...
# 445159                         NaN                         NaN         True
# 445160                         NaN                         NaN          NaN
# 445161                         NaN                         NaN          NaN
# 445162                         NaN                         NaN          NaN
# 445163                         NaN                         NaN         True
#
#        :@computed_region_2dwj_jsy4 :@computed_region_jg9y_a9du  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
# ...                            ...                         ...
# 445159                         NaN                         NaN
# 445160                         NaN                         NaN
# 445161                         NaN                         NaN
# 445162                         NaN                         NaN
# 445163                         NaN                         NaN
#
#        :@computed_region_y6ts_4iup
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ...                            ...
# 445159                         NaN
# 445160                         NaN
# 445161                         NaN
# 445162                         NaN
# 445163                         NaN
#
# [445164 rows x 36 columns]

# %% [markdown]
# # Data Cleaning
#
# ## Feature Selection

# %% [markdown]
# res = res.rename(columns = {'incident_datetime' : 'Incident Datetime', 'incident_date' : 'Incident Date',
#                                           'incident_time' : 'Incident Time', 'incident_year' : 'Incident Year',
#                                           'incident_day_of_week' : 'Incident Day of Week',
#                                           'report_datetime' : 'Report Datetime', 'row_id' : 'Row ID',
#                                           'incident_id' : 'Incident ID',
#                                           'incident_number' : 'Incident Number',
#                                           'cad_number' : 'CAD Number',
#                                           'report_type_code' : 'Report Type Code',
#                                           'report_type_description' : 'Report Type Description',
#                                           'incident_code' : 'Incident Code',
#                                           'incident_category' : 'Incident Category',
#                                           'incident_subcategory' : 'Incident Subcategory',
#                                           'incident_description' : 'Incident Description',
#                                           'resolution' : 'Resolution', 'intersection' : 'Intersection',
#                                           'cnn' : 'CNN',
#                                           'analysis_neighborhood' : 'Analysis Neighborhood',
#                                           'latitude' : 'Latitude', 'longitude' : 'Longitude',
#                                           'point' : 'Point'})

# %% [markdown]
# ## Spelling Normalization

# %%
def clean_incident_category(df) : 
    df['Incident Category'].replace('Offence', 'Offense', regex = True, inplace = True)
    df['Incident Category'].replace('Offenses','Offense',regex=True, inplace = True)
    #df['Incident Category'].replace('Offense Against The Family And Children', 'Family Offense', regex=False, inplace = True)
    df['Incident Category'].replace('Human Trafficking (A), Commercial Sex Acts', 'Human Trafficking', regex=False, inplace = True)
    df['Incident Category'].replace('Human Trafficking, Commercial Sex Acts', 'Human Trafficking', regex=False, inplace = True)
    df['Incident Category'].replace('Human Trafficking (B), Involuntary Servitude', 'Human Trafficking', regex=False, inplace = True)
    df['Incident Category'].replace('Motor Vehicle Theft?', 'Motor Vehicle Theft', regex=False, inplace = True)
    df['Incident Category'].replace('Suspicious Occ', 'Suspicious', regex=False, inplace = True)
    return

# %%
clean_incident_category(res)

# %%
res['Incident Category'].value_counts()
# Out:
# Larceny Theft                              134614
# Other Miscellaneous                         33011
# Malicious Mischief                          28772
# Non-Criminal                                27256
# Assault                                     26586
# Burglary                                    24736
# Motor Vehicle Theft                         20252
# Recovered Vehicle                           15845
# Warrant                                     14935
# Lost Property                               14141
# Fraud                                       13417
# Drug Offense                                10997
# Robbery                                     10521
# Missing Person                              10053
# Suspicious                                   8843
# Disorderly Conduct                           7608
# Offense Against The Family And Children      6145
# Traffic Violation Arrest                     5347
# Miscellaneous Investigation                  4160
# Other Offense                                3796
# Other                                        3539
# Weapons Offense                              2749
# Weapons Carrying Etc                         2495
# Stolen Property                              2363
# Case Closure                                 1976
# Forgery And Counterfeiting                   1820
# Courtesy Report                              1285
# Arson                                        1232
# Traffic Collision                             916
# Civil Sidewalks                               862
# Prostitution                                  853
# Vandalism                                     793
# Embezzlement                                  625
# Fire Report                                   557
# Sex Offense                                   514
# Vehicle Impounded                             321
# Suicide                                       196
# Vehicle Misplaced                             183
# Drug Violation                                147
# Human Trafficking                             126
# Rape                                          107
# Homicide                                       55
# Liquor Laws                                    37
# Gambling                                       22
# Name: Incident Category, dtype: int64

# %%
res_= res.set_index('Incident ID')

# %% [markdown]
# ## Interpreting NaN values
# ### CAD Number
# The Computer Aided Dispatch (CAD) is the system used by the Department of Emergency Management (DEM) to dispatch officers and other public safety personnel. CAD Numbers are assigned by the DEM system and linked to relevant incident reports (Incident Number). Not all Incidents will have a CAD Number. Those filed online via Coplogic (refer to “Filed Online” field) and others not filed through the DEM system will not have CAD Numbers.

# %%
res_cad = res_.copy()
res_cad['CAD Number'] = res_['CAD Number'].fillna(0)

# %%
res_nona = res_cad.copy()
res_nona= res_nona.dropna()

# %%
res_nona
# Out:
#                    Incident Datetime            Incident Date Incident Time  \
# Incident ID
# 618930       2018-01-01T09:26:00.000  2018-01-01T00:00:00.000         09:26
# 618931       2018-01-01T02:30:00.000  2018-01-01T00:00:00.000         02:30
# 618932       2018-01-01T10:00:00.000  2018-01-01T00:00:00.000         10:00
# 618935       2018-01-01T10:03:00.000  2018-01-01T00:00:00.000         10:03
# 618936       2018-01-01T09:01:00.000  2018-01-01T00:00:00.000         09:01
# ...                              ...                      ...           ...
# 1018513      2021-03-30T15:30:00.000  2021-03-30T00:00:00.000         15:30
# 1018606      2021-04-03T13:25:00.000  2021-04-03T00:00:00.000         13:25
# 1018613      2021-04-03T13:58:00.000  2021-04-03T00:00:00.000         13:58
# 1018621      2021-04-03T16:30:00.000  2021-04-03T00:00:00.000         16:30
# 1018493      2021-03-26T13:30:00.000  2021-03-26T00:00:00.000         13:30
#
#             Incident Year Incident Day of Week          Report Datetime  \
# Incident ID
# 618930               2018               Monday  2018-01-01T09:27:00.000
# 618931               2018               Monday  2018-01-01T08:21:00.000
# 618932               2018               Monday  2018-01-01T10:20:00.000
# 618935               2018               Monday  2018-01-01T10:04:00.000
# 618936               2018               Monday  2018-01-01T09:39:00.000
# ...                   ...                  ...                      ...
# 1018513              2021              Tuesday  2021-04-03T06:30:00.000
# 1018606              2021             Saturday  2021-04-03T16:30:00.000
# 1018613              2021             Saturday  2021-04-03T14:11:00.000
# 1018621              2021             Saturday  2021-04-03T17:24:00.000
# 1018493              2021               Friday  2021-03-28T10:50:00.000
#
#                    Row ID Incident Number CAD Number Report Type Code  ...  \
# Incident ID                                                            ...
# 618930        61893007041       171052174  173641140               VS  ...
# 618931        61893105041       180000768  180010668               II  ...
# 618932        61893275000       180000605  180010893               IS  ...
# 618935        61893565015       180000887  180011579               II  ...
# 618936        61893607041       171052958  180011403               VS  ...
# ...                   ...             ...        ...              ...  ...
# 1018513      101851306242       210184224  210831619               IS  ...
# 1018606      101860606244       210206856  210932079               II  ...
# 1018613      101861304014       210206492  210931580               II  ...
# 1018621      101862106242       210206975  210932259               II  ...
# 1018493      101849306244       216035124          0               II  ...
#
#                Incident Category    Incident Subcategory  \
# Incident ID
# 618930         Recovered Vehicle       Recovered Vehicle
# 618931                  Burglary  Burglary - Residential
# 618932            Missing Person          Missing Person
# 618935       Other Miscellaneous                   Other
# 618936         Recovered Vehicle       Recovered Vehicle
# ...                          ...                     ...
# 1018513            Larceny Theft  Larceny - From Vehicle
# 1018606            Larceny Theft  Larceny - From Vehicle
# 1018613                  Assault      Aggravated Assault
# 1018621            Larceny Theft  Larceny - From Vehicle
# 1018493            Larceny Theft  Larceny - From Vehicle
#
#                              Incident Description            Resolution  \
# Incident ID
# 618930                   Vehicle, Recovered, Auto        Open or Active
# 618931        Burglary, Residence, Forcible Entry        Open or Active
# 618932                               Found Person        Open or Active
# 618935                 Driving, No License Issued  Cite or Arrest Adult
# 618936                   Vehicle, Recovered, Auto        Open or Active
# ...                                           ...                   ...
# 1018513      Theft, From Locked Vehicle, $50-$200        Open or Active
# 1018606         Theft, From Locked Vehicle, >$950        Open or Active
# 1018613             Assault, Aggravated, W/ Force        Open or Active
# 1018621      Theft, From Locked Vehicle, $50-$200        Open or Active
# 1018493         Theft, From Locked Vehicle, >$950        Open or Active
#
#                              Intersection       CNN  Analysis Neighborhood  \
# Incident ID
# 618930            03RD ST \ HOLLISTER AVE  20471000  Bayview Hunters Point
# 618931             LISBON ST \ PERSIA AVE  21719000              Excelsior
# 618932           VAN NESS AVE \ WILLOW ST  25189000             Tenderloin
# 618935            BRAZIL AVE \ MISSION ST  21769000          Outer Mission
# 618936       CUSTOM HOUSE PL \ JACKSON ST  24709000              Chinatown
# ...                                   ...       ...                    ...
# 1018513      36TH AVE \ JOHN F KENNEDY DR  32850000       Golden Gate Park
# 1018606           COLUMBUS AVE \ BEACH ST  25598000           Russian Hill
# 1018613               CLAY ST \ LARKIN ST  25297000           Russian Hill
# 1018621             MARINA BLVD \ LYON ST  33625000               Presidio
# 1018493              BALBOA ST \ 18TH AVE  27493000         Outer Richmond
#
#                        Latitude            Longitude  \
# Incident ID
# 618930        37.72171587946975  -122.39594382884452
# 618931       37.722000219874225  -122.43360633930074
# 618932        37.78337048750076  -122.42083185184009
# 618935        37.72468255342173  -122.43479841474401
# 618936       37.796698028315056  -122.40129440446798
# ...                         ...                  ...
# 1018513       37.76996700325964  -122.49526346636263
# 1018606      37.806780111468534   -122.4195772441978
# 1018613       37.79259308227565  -122.41940178531726
# 1018621       37.80472422408812  -122.44827914652447
# 1018493      37.776643927897865  -122.47696485094035
#
#                                                          Point
# Incident ID
# 618930       {'latitude': '37.72171587946975', 'longitude':...
# 618931       {'latitude': '37.722000219874225', 'longitude'...
# 618932       {'latitude': '37.78337048750076', 'longitude':...
# 618935       {'latitude': '37.72468255342173', 'longitude':...
# 618936       {'latitude': '37.796698028315056', 'longitude'...
# ...                                                        ...
# 1018513      {'latitude': '37.76996700325964', 'longitude':...
# 1018606      {'latitude': '37.806780111468534', 'longitude'...
# 1018613      {'latitude': '37.79259308227565', 'longitude':...
# 1018621      {'latitude': '37.80472422408812', 'longitude':...
# 1018493      {'latitude': '37.776643927897865', 'longitude'...
#
# [422138 rows x 22 columns]

# %%
res_nona.keys()
# Out:
# Index(['Incident Datetime', 'Incident Date', 'Incident Time', 'Incident Year',
#        'Incident Day of Week', 'Report Datetime', 'Row ID', 'Incident Number',
#        'CAD Number', 'Report Type Code', 'Report Type Description',
#        'Incident Code', 'Incident Category', 'Incident Subcategory',
#        'Incident Description', 'Resolution', 'Intersection', 'CNN',
#        'Analysis Neighborhood', 'Latitude', 'Longitude', 'Point'],
#       dtype='object')

# %% [markdown]
# ### Writing the CSV file

# %%
res_nona.to_csv('clean_data.csv')

# %% [markdown]
# https://docs.google.com/document/d/1cORUVRe03mA1UtYBlmu6IGJ9N0C_9iZobGFMam2Hb_I/edit#
# <br>
# https://docs.google.com/document/d/18Lek20dH3E03ISEYtzWzkPqJENrNAdmSSCzjnzj50b4/edit
